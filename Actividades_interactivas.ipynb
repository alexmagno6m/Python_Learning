# %% [markdown]
# __Profesor__: Alexander Acevedo Gomez <br>
# __Ingeniero de Sistemas__ - Universidad Nacional de Colombia <br>
# __Magister en Modelado y Simulacion por Computador__ - Universidad Jorge Tadeo Lozano <br>
# Telegram: @Alex6m

# %% [markdown]
# # Actividades Interactivas

# %% [markdown]
# ## Python

# %% [markdown]
# > ### Sopa de letras Tkinter
# >
# > 1. Realice la siguiente sopa de letras, __cuando la termine NO cierre la ventana para que le tomen el tiempo registrado__
# >
# > [Enlace a la sopa de letras](https://www.educaplay.com/learning-resources/29986040-lenguajes_de_programacion_python_tkinter.html)
# >
# > 2. Seleccione al menos tres palabras de la sopa de letras y redacte una frase, por ejemplo:
# >>En `Tkinter` podemos configurar widgets como `Label` y `Frame`
# >
# > 3. Seleccione al menos tres terminos y establezca una relacion entre ellos, por ejemplo:
# >> if → elif → else
# >>
# >> Son componentes de una estructura condicional
# >
# > 4. Escriba 2 palabras cuyo significado no recuerde bien y escriba su definicion

# %% [markdown]
# > #### Propositos de la actividad
# >
# > Una vez terminada la sopa de letras, escriba lo siguiente:
# >
# > Competencia: 2
# >
# > Ambito conceputal: Conceptos de Interfaces Graficas
# >
# > Objetivo: Resolver la sopa de letras completa para recordar la relacion existente entre los terminos propuestos
