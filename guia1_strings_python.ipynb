# %% [markdown]
# __Profesor__: Alexander Acevedo Gomez <br>
# __Ingeniero de Sistemas__ - Universidad Nacional de Colombia <br>
# __Magister en Modelado y Simulacion por Computador__ - Universidad Jorge Tadeo Lozano <br>
# Telegram: @Alex6m

# %% [markdown]
# # Ejercicio taller de cadenas en Python

# %% [markdown]
# Escriba en su cuaderno:

# %% [markdown]
# > Competencia: 2
# >
# > Ambito conceptual: estructura de datos (strings)
# >
# > Objetivo: Transformar correctamente strings empleando con acierto los metodos adecuados según lo visto en clase e investiacion propia.

# %% [markdown]
# ## Parte 1: manipula las cadenas

# %% [markdown]
# 1. Se tiene la siguiente cadena

# %% [markdown]
# ```python
# texto = "aprendiendo python es divertido"
# ```

# %% [markdown]
# > Realiza las siguientes operaciones:
# > - Convierte toda la cadena a mayúsculas.
# > - Convierte toda la cadena a minúsculas.
# > - Convierte la cadena para que cada palabra empiece en mayúscula.
# > - Cuenta cuántas veces aparece la letra “o”.

# %% [markdown]
# 2. Se tiene la siguiente cadena

# %% [markdown]
# ```python
# frase = "   el conocimiento es poder   "
# ```

# %% [markdown]
# > Realiza las siguientes operaciones:
# > - Elimina los espacios al inicio y al final.
# > - Reemplaza la palabra "poder" por "libertad".
# > - Divide la frase en una lista de palabras usando split().
# > - Vuelve a unir las palabras usando join() pero separadas por " - ".

# %% [markdown]
# 3. Copie la siguiente cadena

# %% [markdown]
# ```python
# numero = "4500"
# ```

# %% [markdown]
# > Realiza las siguientes operaciones:
# > - Convierte la cadena a tipo entero.
# > - Verifica si la cadena contiene solo números.
# > - Verifica si la cadena contiene solo letras.
# > - Multiplica el número obtenido por 2 y muestra el resultado.

# %% [markdown]
# 4. Escribe una frase inspiradora de al menos 5 palabras y guárdala en una variable llamada `frase`.

# %% [markdown]
# > Luego realiza:
# > - Convierte la frase a mayúsculas.
# > - Convierte la frase para que cada palabra comience con mayúscula.
# > - Cuenta cuántas letras “a” hay en la frase.

# %% [markdown]
# 5. Escribe una frase sobre tecnología o programación. Luego:

# %% [markdown]
# > - Divide la frase en palabras usando split().
# > - Guarda las palabras en una lista.
# > - Vuelve a unir las palabras usando join() separándolas con " | ".

# %% [markdown]
# 6. Escribe una cadena que contenga un número (como texto). Ejemplo: `"120"`.

# %% [markdown]
# > Luego:
# > - Verifica si la cadena es numérica.
# > - Si es numérica, conviértela a entero.
# > - Multiplica ese número por 5.

# %% [markdown]
# ## Parte 2: Completa o corrige el error

# %% [markdown]
# 7. Este codigo contiene errores, corrigelo para que funcione correctamente.

# %% [markdown]
# ```python
# texto = "la practica hace al maestro"
#
# print(texto.upper)
# print(texto.count("a")
# ```

# %% [markdown]
# > El programa debe:
# > - Mostrar el texto en mayúsculas
# > - Mostrar cuántas veces aparece la letra a

# %% [markdown]
# 8. Completa los espacios para que el programa reemplace una palabra.

# %% [markdown]
# ```python
# frase = "Python es dificil"
#
# nueva_frase = frase.________("dificil", "facil")
#
# print(nueva_frase)
# ```

# %% [markdown]
# > Resultado esperado:
# >
# > ```python
# Python es facil
# ```

# %% [markdown]
# 9. El siguiente programa intenta verificar si una cadena es un número, pero no funciona correctamente.

# %% [markdown]
# ```python
# dato = "1234"
#
# if dato.isalpha():
#     numero = int(dato)
#     print(numero * 2)
# else:
#     print("No es un numero")
# ```

# %% [markdown]
# > El programa debe:
# > - Verificar si la cadena es numérica
# > - Convertirla a entero
# > - Multiplicarla por 2
