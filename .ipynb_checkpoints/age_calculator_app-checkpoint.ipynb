# %% [markdown]
# __Profesor__: Alexander Acevedo Gomez <br>
# __Ingeniero de Sistemas__ - Universidad Nacional de Colombia <br>
# __Magister en Modelado y Simulacion por Computador__ - Universidad Jorge Tadeo Lozano <br>
# Telegram: @Alex6m

# %% [markdown]
# # Age Calculator

# %% [markdown]
# La siguiente App creada en Python calcula la edad exacta de una persona basandose en su dia, mes y año de nacimiento. Para facilitar el calculo se trabajará con la libreria `datetime`

# %% [markdown]
# ## Diseñando el boceto de la interfaz en Pencil

# %% [markdown]
# En Pencil realice segun lo aprendido la siguiente interfaz:

# %% [markdown]
# ![age](age.png)

# %% [markdown]
# Agregue lo siguiente:

# %% [markdown]
# - Cota horizontal: 280px
# - Cota vertical: 300px
# - Color de fondo de su eleccion (background)
# - Color de fuente de su eleccion (foreground)

# %% [markdown]
# ### Primer sello

# %% [markdown]
# Una vez terminado el diseño en pencil escriba los propositos de la clase para obtener el primer sello:

# %% [markdown]
# > - Competencia: 1
# > - Ambito conceptual: diseño de Apps funcionales en Pencil
# > - Objetivo: Diseñar correctamente el boceto grafico de una app que calcula la edad de un usuario, empleando los widgets correspondientes y los tamaños sugeridos.

# %% [markdown]
# ## Escribiendo el codigo en Python

# %% [markdown]
# 1. Cree un nuevo archivo en Python llamado `age_calculator.py`
# 2. Copie el siguiente codigo en ese archivo

# %% [markdown]
# ```python
# from # complete esta linea importando tkinter
# from datetime import date
#
# root = Tk()
# root.geometry('') # Escriba dentro de las comillas las dimensiones de la ventana segun lo visto en clase
# # vertical and horizontal
# root.resizable(False, False)
# root.title('Age calculator')
# statement = Label(root)
# nameValue = StringVar()
# yearValue = StringVar()
# dayValue = StringVar()
# monthValue = StringVar()
# ```

# %% [markdown]
# 3. Copie debajo el siguiente codigo que da el aspecto visual de la interfaz, en esta ocasion se trabajara primero una columna con los labels y despues la otra colunmna con los entrys, complete las lineas que se le solicitan

# %% [markdown]
# ```python
# l1 = Label(text="") # Escriba dentro de las comillas el texto que se debe mostrar
# l1.grid(row=1, column=0)
#
# nameEntry = Entry(root, textvariable=nameValue)
# nameEntry.grid(row=1, column=1, padx=10, pady=10)
# l2 = Label(text="Year: ")
# l2.grid(row=2, column=0)
#
# yearEntry = Entry(root, textvariable=yearValue)
# yearEntry.grid(row=2, column=1, pady=10, padx=10)
#
# l3 = Label(text='Month: ')
# l3.grid(row=, column=)# Escriba la fila y columna donde se posiciona esta etiqueta
#
#
# monthEntry = Entry(root, textvariable=monthValue)
# monthEntry.grid(row=3, column=1, padx=10, pady=10)
#
# l4 = Label(text='Day:')
# l4.grid(row=, column=) # Escriba la fila y columna donde se posiciona esta etiqueta
#
# dayEntry = Entry(root, textvariable=dayValue)
# dayEntry.grid(row=4, column=1, pady=10, padx=10)
#
# button = Button(text='Calculate Age', command=ageCal)
# button.grid(column=1, row=5)
#
# root.mainloop()
# ```

# %% [markdown]
# ## Implementando la funcionalidad

# %% [markdown]
# 1. Ubiquese debajo de la linea donde quedo la sentencia: `monthValue = StringVar()` observe la imagen:

# %% [markdown]
# ![age2](age2.png)

# %% [markdown]
# 2. Debajo copie el siguiente codigo:

# %% [markdown]
# ```python
# def ageCal():
#     global statement
#     statement.destroy()
#     today = date.today()
#     birthDate = date(int(yearEntry.get()), int(monthEntry.get()),
#                      int(dayEntry.get()))
#     age = today.year - birthDate.year
#     if today.month < birthDate.month or today.month == birthDate.month and today.day < birthDate.day:
#         age -= 1
#     statement = Label(text="{}'s age is {}".format(nameValue.get(), age))
#     ls = Label(text='Result')
#     ls.grid(row=6, column=0, padx=10, pady=10)
#     statement.grid(row=6, column=1, pady=15)
# ```

# %% [markdown]
# 3. Pruebe la App escribiendo sus propios datos, el programa debe calcular su edad a traves de un mensaje.

# %% [markdown]
# ## Entendiendo la funcionalidad

# %% [markdown]
# 1. Ahora preguntele a su IA de confianza que analice el siguiente codigo e infiera que funcion cumple, escriba la respuesta en su cuaderno:

# %% [markdown]
# ```python
# age = today.year - birthDate.year
# if today.month < birthDate.month or today.month == birthDate.month and today.day < birthDate.day:
#     age -= 1
# ```

# %% [markdown]
# 2. Finalmente en el mismo chat consulte a la guia que cambios se podrian implementar para que la app calcule la edad indicando los años y los dias, por ejemplo `Juan's age is 14 and 13 days` y escriba la respuesta en su cuaderno.

# %% [markdown]
# ### Segundo sello

# %% [markdown]
# Si su app funciona y contesto las preguntas anteriores en el cuaderno, escriba lo siguiente para obtener el segundo sello:

# %% [markdown]
# > - Competencia: 1
# > - Ambito conceptual: Diseño de apps funcionales en Python
# > - Objetivo: Copiar correctamente el codigo de python completando los elementos faltantes para diseñar una App funcional en Python que calcula la edad.
