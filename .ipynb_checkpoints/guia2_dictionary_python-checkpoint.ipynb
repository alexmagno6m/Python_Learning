# %% [markdown]
# __Profesor__: Alexander Acevedo Gomez <br>
# __Ingeniero de Sistemas__ - Universidad Nacional de Colombia <br>
# __Magister en Modelado y Simulacion por Computador__ - Universidad Jorge Tadeo Lozano <br>
# Telegram: @Alex6m

# %% [markdown]
# # Ejercicio taller diccionarios en Python

# %% [markdown]
# Escriba en su cuaderno

# %% [markdown]
# > Competencia: 2
# >
# > Ambito conceptual: estructura de datos (dictionary)
# >
# > Objetivo: Realizar correctamente operaciones sobre diccionarios empleando los metodos necesarios para obtener el resultado esperado.

# %% [markdown]
# ## Parte 1: Operaciones con diccionarios

# %% [markdown]
# 1. Dado el siguiente diccionario (reemplace con sus propios datos):

# %% [markdown]
# ```python
# estudiante = {
#     "nombre": "Laura",
#     "edad": 16,
#     "curso": "10A",
#     "promedio": 4.5
# }
# ```

# %% [markdown]
# > Realice las siguientes acciones:
# > - Imprime todas las claves del diccionario.
# > - Muestra el valor asociado a "nombre".
# > - Imprime todos los valores.
# > - Muestra los pares clave-valor.

# %% [markdown]
# 2. Se tiene el siguiente diccionario:

# %% [markdown]
# ```python
# producto = {
#     "nombre": "Audífonos",
#     "precio": 120000,
#     "stock": 15
# }
# ```

# %% [markdown]
# > Realiza:
# > - Cambia el precio a 100000.
# > - Agrega una nueva clave "marca" con un valor.
# > - Elimina "stock".
# > - Imprime el diccionario final.

# %% [markdown]
# 3. Con el siguiente diccionario

# %% [markdown]
# ```python
# mascota = {
#     "nombre": "Max",
#     "tipo": "Perro",
#     "edad": 5
# }
# ```

# %% [markdown]
# > Realiza:
# > - Verifica si la clave "edad" existe.
# > - Obtén el valor de "tipo" usando .get().
# > - Agrega "vacunado": True.
# > - Recorre el diccionario e imprime cada clave y valor.

# %% [markdown]
# 4. Crea un diccionario con información sobre tus gustos musicales:
#
# Ejemplo:
# - artista favorito
# - canción favorita
# - género musical
#
# > Luego:
# > - Imprime todas las claves.
# > - Muestra el valor de una clave usando .get().
# > - Agrega un nuevo dato.

# %% [markdown]
# ## Parte 2: Completa codigo faltante o corrige el error

# %% [markdown]
# 5. Observa el siguiente codigo:

# %% [markdown]
# ```python
# persona = {
#     "nombre": "Carlos",
#     "edad": 20
# }
#
# print(persona.nombre)
# persona["edad"] = "veinte"
# del persona["altura"]
# ```

# %% [markdown]
# > Corrige el error

# %% [markdown]
# 6. Completa el codigo para que funcione correctamente

# %% [markdown]
# ```python
# libro = {
#     "titulo": "1984",
#     "autor": "George Orwell"
# }
#
# # Mostrar claves
# print(__________)
#
# # Agregar año
# libro[__________] = 1949
#
# # Mostrar pares clave-valor
# for clave, valor in __________:
#     print(clave, valor)
# ```
